# %%
import requests
from bs4 import BeautifulSoup


year = input("연도를 입력하세요 : ")
month = input("월을 선택하세요 : ")
week = input("주 를 선택하세요 : ")

if len(month) == 1:
    month = "0"+month
else:
    month = month
# test = map(int, year, month, week)

url = f"http://music.naver.com/listen/history/index.nhn?type=TOTAL&year={year}&month={month}&week={week}"

html = requests.get(url).text
soup = BeautifulSoup(html, "lxml")


# soup.find_all(dt)
music = soup.select('a._title')
music_address = [website_ranking_element.get_text() for website_ranking_element in music]
print("[음원 랭킹 순위]")
for k in range(50):
    print("{0}: {1}".format(k+1, music_address[k]))
# Out:
# 연도를 입력하세요 : 2020
# 월을 선택하세요 : 1
# 주 를 선택하세요 : 1
# [음원 랭킹 순위]
# 1: METEOR
# 2: Psycho
# 3: Blueming
# 4: HIP
# 5: Square (2017)
# 6: 아마두 (feat.우원재, 김효은, 넉살, Huckleberry P)
# 7: Love poem
# 8: 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 9: 늦은 밤 너의 집 앞 골목길에서
# 10: 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 11: Into the Unknown
# 12: 사랑이란 멜로는 없어
# 13: 안녕
# 14: 오늘도 빛나는 너에게 (To You My Light) (Feat. 이라온)
# 15: 시간의 바깥
# 16: WINTER FLOWER(雪中梅)(Feat.RM)
# 17: 조금 취했어 (Prod. 2soo)
# 18: Feel Special
# 19: 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 20: 나의 오랜 연인에게
# 21: 시든 꽃에 물을 주듯
# 22: 불티 (Spark)
# 23: 빌었어
# 24: 숨겨진 세상 (Into the Unknown End Credit Version) (“겨울왕국 2”)
# 25: 다시는 사랑하지 않고, 이별에 아파하기 싫어
# 26: 2002
# 27: Show Yourself
# 28: 포장마차
# 29: 먹구름
# 30: 너를 만나
# 31: 니 소식
# 32: 첫 겨울이니까
# 33: bad guy
# 34: 있어줘요
# 35: LION
# 36: 워커홀릭
# 37: 십이월 이십오일의 고백
# 38: 기억해줘요 내 모든 날과 그때를
# 39: 새 사랑
# 40: 비가 내리는 날에는
# 41: 사랑에 연습이 있었다면 (Prod. 2soo)
# 42: 가을밤 떠난 너
# 43: 모든 날, 모든 순간 (Every day, Every Moment)
# 44: 사계 (Four Seasons)
# 45: 날 보러 와요 (Come See Me)
# 46: Señorita
# 47: Popo (How deep is our love?)
# 48: Obsession
# 49: 헤어져줘서 고마워
# 50: 너에게 못했던 내 마지막 말은
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-6963271cd904> in <module>
#      24 print("[음원 랭킹 순위]")
#      25 for k in range(100):
# ---> 26     print("{0}: {1}".format(k+1, music_address[k]))
#
# IndexError: list index out of range

# %%
import requests
from bs4 import BeautifulSoup
import openpyxl

wb = openpyxl.Workbook()
sheet = wb.active
sheet.append(["제목", "채널명", "좋아요수"])

raw = requests.get("https://tv.naver.com/r/")
html = BeautifulSoup(raw.text, 'lxml')

onethree = html.select("div.inner")

for num1 in onethree:
    title = num1.select_one("dt.title").text.strip().replace(",", "")
    channel = num1.select_one("dd.chn").text.strip().replace(",", "")
    like = num1.select_one("span.like").text.strip().replace(",", "").replace("좋아요 수", "")

    sheet.append([title, channel, like])
    
fourhundred = html.select("div.cds_type")

for num2 in fourhundred:
    title = num2.select_one("dt.title").text.strip().replace(",", "")
    channel = num2.select_one("dd.chn").text.strip().replace(",", "")
    like = num2.select_one("span.like").text.strip().replace(",", "").replace("좋아요 수", "")

    sheet.append([title, channel, like])

wb.save("test.xlsx")

# %%
import requests
from bs4 import BeautifulSoup

url = "https://tv.naver.com/r"

html = requests.get(url).text
soup = BeautifulSoup(html, "lxml")
# print(soup)


movie = soup.select('.cds_type')
movie2 = soup.select('.cds_info')
movie3 = soup.select('.title')
movie4 = soup.select('tooltip')
movie_name = [website_ranking_element.get_text() for website_ranking_element in movie4]
for k in movie_name:
    print("{0}".format(k))
        
        
print()
print()
print()

hit = soup.select('.cds_info')
hit2 = soup.select('.meta')
hit3 = soup.select('.hit')

hit_number = [test.get_text() for test in hit3]
for k in hit_number:
           print(k)

        
print()
print()
print()
like = soup.select('.cds_info')
like2 = soup.select('.meta')
like3 = soup.select('.like')

hit_number = [test.get_text() for test in like3]
for k in hit_number:
           print(k)
# Out:
# 임영웅 ‘옛사랑’ ♪ 감성 장인 히어로 💧
# [키스 엔딩] ＂보고 싶었어...＂ 김하늘♥이도현의 변하지 않은 사랑
# 17살 차이나는 박휘순♥천예지 부부!! 나이보단 사랑이 우선이다..☆
# [선공개] 주저앉은 김범! 이동욱과 아귀의 숲 탈출 포기?
# 이지아, 진짜 친딸 안 뒤 조수민이 당한 과거 회상에 ‘눈물’
# 이지아, 이철민이 말한 친딸 관련된 진실에 ‘오열’ (ft. 엄기준 소름)
# 함소원의 끈질긴 유혹😘 둘째 프로젝트 성공?!
# “여기 아무 일도 없었어요?” 이지아, 평화로운 파티장에 당황!
# '이재영-김연경 44점 합작' 흥국생명, 현대건설 꺾고 4연승
# “후식은 중국집” 김호중×현주엽, 끝나지 않는 먹레이스!
# 나왔다! 찬원이의 필살기↗ ‘미운 사내’ ♬
# 어린 신부의 저녁 밥 차리기↗ 무 없는 소고기 뭇국ㅋㅋ
# 30대에 얼린 ‘냉동 난자’ 셀프 운반 함소원🏃🏻
# [11월 9일 예고] “역시 기억이 안 나나요?” 김소연, 유진 향한 날카로운 심문!
# [파격엔딩] 조리원에 불어온 새바람, 강력한 분유파 최리 등장! 그리고 의문의 선물
# 33세➜40세😱 4년 사이 증가한 난소 나이 ㅠㅠ
# "김정은, '피살' 경위 조사 지시"…코로나에 공포감
# “잘못된 소문이에요” 김소연, 용의자 벗어나기 위한 거짓말!
# 진화 살려~ 메기 매운탕 한입 먹고 우웩🤮
# 탈락석으로 ‘가지마’♪ 포천의 아들 임영웅 아자!
# '말이 안 나오는 활약' 54득점으로 오늘 경기 원맨쇼를 보여준 케이타
# 포체티노가 돌아왔다... 그가 밝힌 감독 계획과 토트넘에 대한 생각 [오늘의 가십]
# [단독] 김윤배 가족들도 온갖 집안일 시켜…"머슴 생활"
# 프란체스카의 환생..?! 진화 집 나갈 비주얼ㅋㅋ
# [영상] 6살 뒷목 잡고 바닥 내동댕이…추가 학대 정황
# 감성장인 갑니다...임영웅 ‘그리움만 쌓이네’♬
# “너 어제부터 왜 그렇게 예민해?” 한지현, 불안해하는 최예빈 도발!
# SK감독, 선동열 포함 3인 압축 / 김경문 재계약? / 양현종 美가능성 / 최형우 비매너였나
# 영탁 ‘붓’♫ 콜센타의 자존심을 보여줘😎
# “요리 못하겠어요” 김호중, 끊임없이 감시하는 먹보스 현주엽에 고통!
# [에필로그] 과거 테이프에서 이도현의 모습을 보게 된 최보민 (ㅇ_ㅇ)?!

# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-165-0bc37ffa0d02> in <module>
# ----> 1 from selenium import webdriver
#       2 from bs4 import BeautifulSoup
#       3
#       4 driver = webdriver.Chrome('c:/chromedriver')
#       5 driver.implicitly_wait(3)
#
# ModuleNotFoundError: No module named 'selenium'

# %%
import requests
from bs4 import BeautifulSoup

url1to50 = "http://music.naver.com/listen/history/index.nhn?type=DOMESTIC&year=2017&month=12&week=1&page=1"    
url51to100 = "http://music.naver.com/listen/history/index.nhn?type=DOMESTIC&year=2017&month=12&week=1&page=2"
# url = "http://music.naver.com/listen/top100.nhn?domain=TOTAL&page=1"
# url = "http://music.naver.com/listen/top100.nhn?domain=TOTAL&page=2"
    
html_music1to50 = requests.get(url1to50).text
soup_music1to50 = BeautifulSoup(html_music1to50, "lxml")

titles1to50 = soup_music1to50.select('a._title span.ellipsis') 
artists1to50 = soup_music1to50.select('td._artist a')

music_titles1to50 = [title.get_text() for title in titles1to50]
music_artists1to50 = [artist.get_text().strip() for artist in artists1to50 ]

for k in range(7):
    print("{0}: {1} / {2}".format(k+1, music_titles1to50[k], music_artists1to50[k]))

print("-----------------------------------------")

html_music51to100 = requests.get(url51to100).text
soup_music51to100 = BeautifulSoup(html_music51to100, "lxml")

titles51to100 = soup_music51to100.select('a._title span.ellipsis') 
artists51to100 = soup_music51to100.select('td._artist a')

music_titles51to100 = [title.get_text() for title in titles51to100]
music_artists51to100 = [artist.get_text().strip() for artist in artists51to100]
   
num = 50
for k in range(10):
    test = k+1
    print(str(num+1)+": {1} / {2}".format(test, music_titles51to100[k], music_artists51to100[k]))
    num=num+1
# Out:
# 1: 눈 (Feat. 이문세) / Zion.T
# 2: 기억의 빈자리 / 나얼
# 3: 선물 / 멜로망스(Melomance)
# 4: Beautiful / Wanna One(워너원)
# 5: 좋아 / 민서
# 6: 피카부 (Peek-A-Boo) / Red Velvet (레드벨벳)
# 7: 좋니 / 윤종신
# -----------------------------------------
# 51: 가시나 / 선미
# 52: all of my life / 박원
# 53: To Be One (Outro.) / Wanna One(워너원)
# 54: 비행운 / 문문(MoonMoon)
# 55: 고민보다 Go / 방탄소년단
# 56: 빨간 맛 (Red Flavor) / Red Velvet (레드벨벳)
# 57: 덜덜덜 / EXID
# 58: 밤이 되니까 / 펀치 (Punch)
# 59: 피 땀 눈물 / 방탄소년단
# 60: Blue / 볼빨간사춘기

# %%
import urllib.request
import urllib.parse
from bs4 import BeautifulSoup

urladdress1 = 'https://www.melon.com/new/index.htm'
header01 = {'User-Agent' : 'Mozilla/5.0"'}
modi01 = urllib.request.Request(urladdress1, headers = header01)

htmlcontent1 = urllib.request.urlopen(modi01).read()
verification1 = BeautifulSoup(htmlcontent1, 'html.parser')

Sorted_Data1 = verification1.select('.ellipsis.rank01')
Sorted_Data2 = verification1.select('.ellipsis.rank01')

int01 = 0

for j in Sorted_Data1:
    int01 = int01 + 1
    
print('크롤링할 총 개수 :', int01)

for i in range(int01):
    print(str(i+1)+'번째', end=" ")
    print(Sorted_Data2[i].a.text)

# %%
import requests
from bs4 import BeautifulSoup

# url = 'https://www.melon.com/new/index.htm'
url1 = 'https://www.melon.com/new/index.htm#params%5BareaFlg%5D=I&po=pageObj&startIndex=1'
# url2 = 'https://www.melon.com/new/index.htm#params%5BareaFlg%5D=I&po=pageObj&startIndex=51'
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}
html = requests.get(url, headers = headers).text
soup = BeautifulSoup(html, "lxml")

titles = soup.select("div.rank01 span a")
art = soup.select("div.rank02 span a")

melon_title = [title.get_text() for title in titles]
melon_art = [title.get_text() for title in art]
# print(melon_title)
# print(melon_art)


for k in range(50):
    print("{0}: {1} / {2}".format(k+1, melon_title[k], melon_art[k]))

    

# headers1 = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}
# html1 = requests.get(url2, headers = headers).text
# soup1 = BeautifulSoup(html, "lxml")

# titles = soup.select("div.rank01 span a")
# art = soup.select("div.rank02 span a")

# melon_title = [title.get_text() for title in titles]
# melon_art = [title.get_text() for title in art]
# # print(melon_title)
# # print(melon_art)
# Out:
# 1: HERO / 임영웅
# 2: 호랑이는 죽어서 가죽을, 우리는 이름을 / 홈보이 (Homeboy)
# 3: 떨어져 (Please Go Away) / 에네이 에미 (Enei Emi)
# 4: 싸이코4U / NIDA
# 5: AYA / 걸카인드 (GIRLKIND)
# 6: SOON (Feat. BewhY) / 마마무 (Mamamoo)
# 7: Bangkok (Stay Home) / 다이나믹 듀오
# 8: By your side (Feat. E.N.D., SLOC) / 뷰티핸섬
# 9: 어쩌면 오래전부터 / TSLW
# 10: Winter again / 캡틴플래닛
# 11: 얘랑 있을 때 좋다(with 김국헌 of 비오브유) / 이은아
# 12: I'm alone / Yolk
# 13: Wind, Star (feat. 이상훈 of 훈스 (HOONS)) / 어쿠스틱 콜라보
# 14: 백일홍 / The Hills (더 힐스)
# 15: 잔상 (Vocal. 정구영) / 릴리노트 (Lilynote)
# 16: 귀가 (With 타미즈) / 조명섭
# 17: 너라는 하루를 살아 / 김현수 (F-IV)
# 18: 그때 생각나?(Remember that time?) / 42kgb
# 19: i got you / 주호
# 20: On The Radio (With SERO) / 베이비블루(BABY BLUE)
# 21: 서울 / Jimmy Brown
# 22: Love Killa / SUDI
# 23: SALUTE / 임예송
# 24: 비행기 모드 (Feat. 바끼리, BRADYSTREET) / 몬스타엑스
# 25: 안돼요 / AB6IX (에이비식스)
# 26: G.B.T.B. (Strong Dragon Remix) / 나왔구나 김비노
# 27: OFF / 홍진영
# 28: I need you. Period. / VERIVERY
# 29: 좋아 좋아 / 새벽두시
# 30: 강을 향해 간다 / Kim Jeong_uk(김정욱)
# 31: INTRCRSE (Feat. 바끼리) / 정다경
# 32: Fxxkin Insomnia / 스마일리스마일 (SmileySmile)
# 33: 소년 / DOPA
# 34: MOVIE (Feat. Rohann) / MÖA
# 35: 텅 비었던(ft. 서한) / 신지민
# 36: DIVIN' (Feat. z4vwm (잡음), JUICY KID) / 정진우
# 37: 그대 그리운 날 / Xbf
# 38: Love you Love you (feat.더 브릿지(The Bridge)) / 온리차일드 (ONLICHILD)
# 39: Labyrinth / 설가령
# 40: Be bop a lula / 브런치 레시피 (Brunch recipe)
# 41: Lazy Seoul (레이지 서울) / 정주 (Jungju)
# 42: 온도차 / 얼스 (Earls)
# 43: 내버려둬(NOYB) / 이철호
# 44: 태양 / 제이켠
# 45: Overdose (feat. Tommy Strate) / 화자 (HWAJA)
# 46: My Love / BXK
# 47: 우리 멀리 떠날까 (feat. 정기고) / 이준형
# 48: minimal warm (취향저격 그녀 X 찬열 (CHANYEOL)) / Claire Hau (클레어 하우)
# 49: My Universe (Prod. by Minit) / 다비치
# 50: Traveler (feat. Zooy, Vibin) / 고닥
