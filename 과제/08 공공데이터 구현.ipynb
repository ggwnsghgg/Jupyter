# %%
import pandas as pd
df1 = pd.read_csv("C:/myPyCode/baby.csv",  encoding = 'cp949')
df1
# Out:
#       구분                구분명 연도별값(07) 연도별값(08) 연도별값(09) 연도별값(10) 연도별값(11)  \
# 0     00                연도별     2010     2011     2012     2013     2014
# 1     01                 0세    93266    91526    93914    84066    83711
# 2     02             출산율(%)     1.02     1.01     1.06     0.97     0.98
# 3     03                연도별   588203   579444   581694   574126   559662
# 4     04         영유아인구수(명)계   255247   251951   256528   249819   242963
# 5     05  영유아인구수(명)영아(0~2)세   247386   250815   246456   239724   237084
# 6   05_1                NaN    85570    76678    78710    84583    79615
# 7     06  영유아인구수(명)유아(3~5)세   199651   208985   234597   238581   240049
# 8     07             어린이집계수    33.9%    36.1%    40.3%    41.6%    42.9%
# 9     08            어린이집계비율   104669   111495   134174   136696   139314
# 10    09       어린이집영아(0~2)세    94982    97490   100423   101885   100735
# 11    10       어린이집유아(3~5)세    78644    81203    87969    92369    91169
# ...
